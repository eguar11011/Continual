# %%
# Subspace Similarity – Promedio por capa (Tarea 9)   *sin* banda de desviación estándar
import json, numpy as np, matplotlib.pyplot as plt
from pathlib import Path

# ───────── 1. Ruta al JSON ─────────
json_path = Path("merged_similarity_t4.json")   # cambia si es necesario
assert json_path.exists(), f"No se encontró {json_path}"

# ───────── 2. Cargar datos ─────────
with open(json_path) as f:
    root = json.load(f)

list_layers = [item.get("data", item)["layers"] for item in root]
print(f"Experimentos cargados: {len(list_layers)}")

# Capas en el orden deseado
STAGE_ORDER = [
    "backbone.conv1", "backbone.bn1", "backbone.layer1.1",
    "backbone.layer2.1", "backbone.layer3.1", "backbone.layer4.1"
]
ETIQUETAS = ["Capa 0", "Capa 1", "Capa 2", "Capa 3", "Capa 4", "Capa 5"]

# ───────── 3. Promedio por capa ─────────
common = set(list_layers[0])
for d in list_layers[1:]:
    common &= d.keys()

layers_common = [k for k in STAGE_ORDER if k in common]
raw   = np.array([[d[k] for k in layers_common] for d in list_layers], dtype=float)
mean  = raw.mean(axis=0)

print("\nPromedio por capa:")
for k, m in zip(layers_common, mean):
    print(f"  {k:20s}  {m:.4f}")

# ───────── 4. Gráfica del promedio ─────────
orig_x = np.arange(len(mean))

plt.figure(figsize=(7, 4.5))
plt.plot(orig_x, mean, lw=2, marker="o", label="Promedio")
plt.xticks(orig_x, ETIQUETAS[:len(mean)], rotation=45)
plt.ylim(0, 1)
plt.xlabel("Stage"); plt.ylabel("Subspace Similarity")
plt.title("Subspace Similarity · Promedio (Tarea 4)")
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.legend(frameon=False)
plt.tight_layout()
plt.show()

# Para guardar la figura:
# plt.savefig("subspace_mean.png", dpi=300, bbox_inches="tight")
# Out:
# Experimentos cargados: 10
#
# Promedio por capa:
#   backbone.conv1        0.8986
#   backbone.bn1          0.8993
#   backbone.layer1.1     0.5883
#   backbone.layer2.1     0.6023
#   backbone.layer3.1     0.3692
#   backbone.layer4.1     0.2592

# %%
# Subspace Similarity – Promedio por capa (Tarea 9)   *sin* banda de desviación estándar
import json, numpy as np, matplotlib.pyplot as plt
from pathlib import Path

# ───────── 1. Ruta al JSON ─────────
json_path = Path("merged_similarity_ck4.json")   # cambia si es necesario
assert json_path.exists(), f"No se encontró {json_path}"

# ───────── 2. Cargar datos ─────────
with open(json_path) as f:
    root = json.load(f)

list_layers = [item.get("data", item)["layers"] for item in root]
print(f"Experimentos cargados: {len(list_layers)}")

# Capas en el orden deseado
STAGE_ORDER = [
    "backbone.conv1", "backbone.bn1", "backbone.layer1.1",
    "backbone.layer2.1", "backbone.layer3.1", "backbone.layer4.1"
]
ETIQUETAS = ["Capa 0", "Capa 1", "Capa 2", "Capa 3", "Capa 4", "Capa 5"]

# ───────── 3. Promedio por capa ─────────
common = set(list_layers[0])
for d in list_layers[1:]:
    common &= d.keys()

layers_common = [k for k in STAGE_ORDER if k in common]
raw   = np.array([[d[k] for k in layers_common] for d in list_layers], dtype=float)
mean  = raw.mean(axis=0)

print("\nPromedio por capa:")
for k, m in zip(layers_common, mean):
    print(f"  {k:20s}  {m:.4f}")

# ───────── 4. Gráfica del promedio ─────────
orig_x = np.arange(len(mean))

plt.figure(figsize=(7, 4.5))
plt.plot(orig_x, mean, lw=2, marker="o", label="Promedio")
plt.xticks(orig_x, ETIQUETAS[:len(mean)], rotation=45)
plt.ylim(0, 1)
plt.xlabel("Stage"); plt.ylabel("Subspace Similarity")
plt.title("Subspace Similarity · Promedio (Tarea 4)")
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.legend(frameon=False)
plt.tight_layout()
plt.show()

# Para guardar la figura:
# plt.savefig("subspace_mean.png", dpi=300, bbox_inches="tight")
# Out:
# Experimentos cargados: 10
#
# Promedio por capa:
#   backbone.conv1        0.8677
#   backbone.bn1          0.8617
#   backbone.layer1.1     0.8857
#   backbone.layer2.1     0.8545
#   backbone.layer3.1     0.6028
#   backbone.layer4.1     0.5823
